# %%
# I checked and we have no dupes or NA to drop

sdd_df = pd.read_csv("data/SoftwareDefectDataset.csv")
sdd_df.describe
# Out:
# <bound method NDFrame.describe of           LOC     CYCLO    LENGTH    VOLUME  DIFFICULTY  INT_FAN_IN  \
# 0    0.779239  0.478261  0.274048  0.544918    0.564121    0.222222
# 1    0.595156  0.608696  0.742561  0.758597    0.450649    0.222222
# 2    0.895502  0.000000  0.968166  0.754277    0.672996    1.000000
# 3    0.782007  0.565217  0.164706  0.017766    0.584106    0.000000
# 4    0.757785  0.217391  0.560900  0.126125    0.526050    0.555556
# ..        ...       ...       ...       ...         ...         ...
# 995  0.577855  0.739130  0.331488  0.091950    0.603102    1.000000
# 996  0.500346  0.304348  0.719031  0.553453    0.511870    0.666667
# 997  0.155017  0.869565  0.843253  0.641748    0.059249    1.000000
# 998  0.367474  0.608696  0.803806  0.703938    0.287075    0.111111
# 999  0.077509  0.000000  0.183391  0.373249    0.091656    0.333333
#
#      INT_FAN_OUT  NUM_OPERATORS  NUM_OPERANDS  BRANCH_COUNT  DEFECT_LABEL
# ...
